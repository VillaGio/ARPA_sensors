# %%
import matplotlib.pyplot as plt
import seaborn as sn
from matplotlib import rcParams
import pandas as pd
import numpy as np
data1995 = pd.read_pickle('df_1995.h5')
data2000 = pd.read_pickle('df_2000.h5')
data2004 = pd.read_pickle('df_2004.h5')
data2007 = pd.read_pickle('df_2007.h5')
data2010 = pd.read_pickle('df_2010.h5')
data2011 = pd.read_pickle('df_2011.h5')
data2012 = pd.read_pickle('df_2012.h5')
data2013 = pd.read_pickle('df_2013.h5')
data2014 = pd.read_pickle('df_2014.h5')
data2015 = pd.read_pickle('df_2015.h5')
data2016 = pd.read_pickle('df_2016.h5')
data2017 = pd.read_pickle('df_2017.h5')
data2018 = pd.read_pickle('df_2018.h5')
data2019 = pd.read_pickle('df_2019.h5')
data2020 = pd.read_pickle('df_2020.h5')
data2021 = pd.read_pickle('df_2021.h5')

# %%
stazioni=pd.read_csv('Stazioni_qualit__dell_aria.csv')
stazioni.head()
# Out:
#    IdSensore           NomeTipoSensore UnitaMisura  Idstazione  \
# 0       6398           Ossidi di Azoto       µg/m³         554
# 1       5749                     Ozono       µg/m³         554
# 2       5735                     Ozono       µg/m³         576
# 3      10197  Particelle sospese PM2.5       µg/m³         697
# 4      20465               BlackCarbon       µg/m³         548
#
#                       NomeStazione  Quota Provincia              Comune  \
# 0              Saronno v.Santuario  212.0        VA             Saronno
# 1              Saronno v.Santuario  212.0        VA             Saronno
# 2      Merate v. Madonna di Loreto  279.0        LC              Merate
# 3  Borgofranco sul Po loc. Bonizzo   14.0        MN  Borgofranco sul Po
# 4                  Milano v.Senato  118.0        MI              Milano
#
#   Storico   DataStart    DataStop  Utm_Nord  UTM_Est        lat        lng  \
# ...

# %%
d2021pm10 = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
for i in range(len(d2021pm10)):
    d2021pm10['Data'][i]=str(d2021pm10['Data'][i].day)+'-'+str(d2021pm10['Data'][i].month)+'-'+str(d2021pm10['Data'][i].year)
d2021pm10 = d2021pm10.groupby(["Data"]).mean()
d2020pm10 = pd.merge(left=data2020[data2020['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2020pm10 = d2020pm10.groupby(["Data"]).mean()
d2019pm10 = pd.merge(left=data2019[data2019['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2019pm10 = d2019pm10.groupby(["Data"]).mean()
d2018pm10 = pd.merge(left=data2018[data2018['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2018pm10 = d2018pm10.groupby(["Data"]).mean()
d2017pm10 = pd.merge(left=data2017[data2017['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2017pm10 = d2017pm10.groupby(["Data"]).mean()
d2016pm10 = pd.merge(left=data2016[data2016['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2016pm10 = d2016pm10.groupby(["Data"]).mean()
d2015pm10 = pd.merge(left=data2015[data2015['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2015pm10 = d2015pm10.groupby(["Data"]).mean()
d2014pm10 = pd.merge(left=data2014[data2014['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2014pm10 = d2014pm10.groupby(["Data"]).mean()
d2013pm10 = pd.merge(left=data2013[data2013['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2013pm10 = d2013pm10.groupby(["Data"]).mean()
d2012pm10 = pd.merge(left=data2012[data2012['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2012pm10 = d2012pm10.groupby(["Data"]).mean()
d2011pm10 = pd.merge(left=data2011[data2011['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2011pm10 = d2011pm10.groupby(["Data"]).mean()
d2010pm10 = pd.merge(left=data2010[data2010['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2010pm10 = d2010pm10.groupby(["Data"]).mean()
d2007pm10 = pd.merge(left=data2007[data2007['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2007pm10 = d2007pm10.groupby(["Data"]).mean()
d2004pm10 = pd.merge(left=data2004[data2004['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2004pm10 = d2004pm10.groupby(["Data"]).mean()
d2000pm10 = pd.merge(left=data2000[data2000['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d2000pm10 = d2000pm10.groupby(["Data"]).mean()
d1995pm10 = pd.merge(left=data1995[data1995['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="PM10") | (stazioni['NomeTipoSensore']=="PM10 (SM2005)")], how="inner")
d1995pm10 = d1995pm10.groupby(["Data"]).mean()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/2750455044.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021pm10['Data'][i]=str(d2021pm10['Data'][i].day)+'-'+str(d2021pm10['Data'][i].month)+'-'+str(d2021pm10['Data'][i].year)

# %%
grouped = d2021pm10.groupby(["Data"]).mean()
pm10_2021_plot = grouped["Valore"]
plt.plot(pm10_2021_plot, marker='o')
plt.title("2021 average measurement of PM10 in Lombardy")
plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()

# %%
d2021BiAz = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="Biossido di Azoto")], how="inner")
for i in range(len(d2021BiAz)):
    d2021BiAz['Data'][i]=str(d2021BiAz['Data'][i].day)+'-'+str(d2021BiAz['Data'][i].month)+'-'+str(d2021BiAz['Data'][i].year)
d2021BiAz = d2021BiAz.groupby(["Data"]).mean()
BiAz_2021_plot = d2021BiAz["Valore"]
plt.plot(BiAz_2021_plot, marker='o')
plt.title("2021 average measurement of NO2 in Lombardy")
plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='NO2 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/505602642.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021BiAz['Data'][i]=str(d2021BiAz['Data'][i].day)+'-'+str(d2021BiAz['Data'][i].month)+'-'+str(d2021BiAz['Data'][i].year)

# %%
d2021OsAz = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="Ossidi di Azoto")], how="inner")
for i in range(len(d2021OsAz)):
    d2021OsAz['Data'][i]=str(d2021OsAz['Data'][i].day)+'-'+str(d2021OsAz['Data'][i].month)+'-'+str(d2021OsAz['Data'][i].year)
d2021OsAz = d2021OsAz.groupby(["Data"]).mean()
OsAz_2021_plot = d2021OsAz["Valore"]
plt.plot(OsAz_2021_plot, marker='o')
plt.title("2021 average measurement of NO in Lombardy")
plt.ylabel("concentration in µg/m3")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/941517057.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021OsAz['Data'][i]=str(d2021OsAz['Data'][i].day)+'-'+str(d2021OsAz['Data'][i].month)+'-'+str(d2021OsAz['Data'][i].year)
# No handles with labels found to put in legend.

# %%
d2021CO = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="Monossido di Carbonio")], how="inner")
for i in range(len(d2021CO)):
    d2021CO['Data'][i]=str(d2021CO['Data'][i].day)+'-'+str(d2021CO['Data'][i].month)+'-'+str(d2021CO['Data'][i].year)
d2021CO = d2021CO.groupby(["Data"]).mean()
CO_2021_plot = d2021CO["Valore"]
plt.plot(CO_2021_plot, marker='o')
plt.title("2021 average measurement of CO in Lombardy")
plt.ylabel("concentration in µg/m3")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/1779867503.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021CO['Data'][i]=str(d2021CO['Data'][i].day)+'-'+str(d2021CO['Data'][i].month)+'-'+str(d2021CO['Data'][i].year)
# No handles with labels found to put in legend.

# %%
d2021O3 = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="Ozono")], how="inner")
for i in range(len(d2021O3)):
    d2021O3['Data'][i]=str(d2021O3['Data'][i].day)+'-'+str(d2021O3['Data'][i].month)+'-'+str(d2021O3['Data'][i].year)
d2021O3 = d2021O3.groupby(["Data"]).mean()
O3_2021_plot = d2021O3["Valore"]
plt.plot(O3_2021_plot, marker='o')
plt.title("2021 average measurement of O3 in Lombardy")
#plt.hlines(y=120, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='O3 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/1884185916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021O3['Data'][i]=str(d2021O3['Data'][i].day)+'-'+str(d2021O3['Data'][i].month)+'-'+str(d2021O3['Data'][i].year)
# No handles with labels found to put in legend.

# %%
plt.plot(O3_2021_plot, marker='o')
plt.title("2021 average measurement of O3 in Lombardy")
plt.hlines(y=120, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='O3 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()

# %%
d2021PM2p5 = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="Particelle sospese PM2.5")], how="inner")
for i in range(len(d2021PM2p5)):
    d2021PM2p5['Data'][i]=str(d2021PM2p5['Data'][i].day)+'-'+str(d2021PM2p5['Data'][i].month)+'-'+str(d2021PM2p5['Data'][i].year)
d2021PM2p5 = d2021PM2p5.groupby(["Data"]).mean()
PM2p5_2021_plot = d2021PM2p5["Valore"]
plt.plot(PM2p5_2021_plot, marker='o')
plt.title("2021 average measurement of PM2.5 in Lombardy")
plt.hlines(y=25, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM2.5 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/1733976270.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021PM2p5['Data'][i]=str(d2021PM2p5['Data'][i].day)+'-'+str(d2021PM2p5['Data'][i].month)+'-'+str(d2021PM2p5['Data'][i].year)

# %% [markdown]
# il particolato totale sospeso non viene più misurato dal 2017
# Via con gli altri anni

# %% [markdown]
# allora filtrare mergiare raggruppare

# %%
pm10 = pd.concat([d2021pm10, d2020pm10, d2019pm10, d2018pm10, d2017pm10, d2016pm10, d2015pm10, d2014pm10, d2013pm10, d2012pm10, d2011pm10, d2010pm10,
                 d2007pm10, d2004pm10, d2000pm10, d1995pm10])

# %%
pm10 = pm10.sort_values("Data")

# %%
plt.plot(pm10['Valore'], marker='o')
#plt.hlines(y=50, xmin=9200, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.title("Time seres of PM10 measurements")
plt.ylabel("concentration in µg/m3")
plt.xlabel("Year")
plt.rcParams["figure.figsize"] = (15,6)

# %% [markdown]
# I boxplot a me piacciono

# %%
pm10_2021_corr = d2021pm10['Valore'][1:]
pm10_2021_corr.index = range(len(pm10_2021_corr))
pm10_2020_corr = pd.concat([d2020pm10['Valore'][1:59],d2020pm10['Valore'][60:]])
pm10_2020_corr.index = range(len(pm10_2020_corr))
pm10_2019_corr = d2019pm10['Valore'][1:]
pm10_2019_corr.index = range(len(pm10_2019_corr))
pm10_2018_corr = d2018pm10['Valore'][1:]
pm10_2018_corr.index = range(len(pm10_2018_corr))
pm10_2017_corr = d2017pm10['Valore'][1:]
pm10_2017_corr.index = range(len(pm10_2017_corr))
pm10_2016_corr = pd.concat([d2016pm10['Valore'][1:59],d2016pm10['Valore'][60:]])
pm10_2016_corr.index = range(len(pm10_2016_corr))
pm10_2015_corr = d2015pm10['Valore']
pm10_2015_corr.index = range(len(pm10_2015_corr))
pm10_2014_corr = d2014pm10['Valore'][1:]
pm10_2014_corr.index = range(len(pm10_2014_corr))
pm10_2013_corr = d2013pm10['Valore'][1:]
pm10_2013_corr.index = range(len(pm10_2013_corr))
pm10_2012_corr = pd.concat([d2012pm10['Valore'][1:59],d2012pm10['Valore'][60:]])
pm10_2012_corr.index = range(len(pm10_2012_corr))
pm10_2011_corr = d2011pm10['Valore'][1:]
pm10_2011_corr.index = range(len(pm10_2011_corr))
pm10_2010_corr = d2010pm10['Valore'][732:]
pm10_2010_corr.index = range(len(pm10_2010_corr))
pm10_2009_corr = d2010pm10['Valore'][367:731]
pm10_2009_corr.index = range(len(pm10_2009_corr))
pm10_2008_corr = pd.concat([d2010pm10['Valore'][1:59],d2010pm10['Valore'][60:366]])
pm10_2008_corr.index = range(len(pm10_2008_corr))
pm10_2007_corr = d2007pm10['Valore'][731:]
pm10_2007_corr.index = range(len(pm10_2007_corr))
pm10_2006_corr = d2007pm10['Valore'][366:730]
pm10_2006_corr.index = range(len(pm10_2006_corr))
pm10_2005_corr = d2007pm10['Valore'][1:365]
pm10_2005_corr.index = range(len(pm10_2005_corr))
pm10_2004_corr = pd.concat([d2004pm10['Valore'][1096:1154],d2004pm10['Valore'][1155:]])
pm10_2004_corr.index = range(len(pm10_2004_corr))
pm10_2003_corr = d2004pm10['Valore'][731:1095]
pm10_2003_corr.index = range(len(pm10_2003_corr))
pm10_2002_corr = d2004pm10['Valore'][366:730]
pm10_2002_corr.index = range(len(pm10_2002_corr))
pm10_2001_corr = d2004pm10['Valore'][1:365]
pm10_2001_corr.index = range(len(pm10_2001_corr))
pm10_2000_corr = pd.concat([d2000pm10['Valore'][1177:1235],d2000pm10['Valore'][1236:]])
pm10_2000_corr.index = range(len(pm10_2000_corr))
pm10_1999_corr = d2000pm10['Valore'][812:1176]
pm10_1999_corr.index = range(len(pm10_1999_corr))
# gli anni successivi sono decisamente incompleti

# %%
lista=[1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([pm10_1999_corr, pm10_2000_corr,  pm10_2001_corr,  pm10_2002_corr,  pm10_2003_corr,
             pm10_2004_corr, pm10_2005_corr,  pm10_2006_corr,  pm10_2007_corr,  pm10_2008_corr,
             pm10_2009_corr, pm10_2010_corr,  pm10_2011_corr,  pm10_2012_corr,  pm10_2013_corr,
             pm10_2014_corr, pm10_2015_corr,  pm10_2016_corr,  pm10_2017_corr,  pm10_2018_corr,
             pm10_2019_corr, pm10_2020_corr,  pm10_2021_corr], positions = lista, patch_artist = True)

plt.title("Boxplots of PM10 measurements by year")
plt.hlines(y=50, xmin=1999, xmax=2021, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Year")
plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()

# %% [markdown]
# Diminuzione negli anni di concentrazione

# %% [markdown]
# Statistiche descrittive pm10

# %%
descrittive = pd.concat([d2021pm10['Valore'].describe(),d2020pm10['Valore'].describe(), d2019pm10['Valore'].describe(),
                        d2018pm10['Valore'].describe(), d2017pm10['Valore'].describe(), d2016pm10['Valore'].describe(),
                        d2015pm10['Valore'].describe(), d2014pm10['Valore'].describe(), d2013pm10['Valore'].describe(),
                        d2012pm10['Valore'].describe(), d2011pm10['Valore'].describe(), d2010pm10['Valore'][731:].describe(), 
                        d2010pm10['Valore'][366:731].describe(), d2010pm10['Valore'][:366].describe(), d2007pm10['Valore'][730:].describe(),
                        d2007pm10['Valore'][365:730].describe(), d2007pm10['Valore'][:365].describe(), d2004pm10['Valore'][1095:].describe(),
                        d2004pm10['Valore'][730:1095].describe(), d2004pm10['Valore'][365:730].describe(), d2004pm10['Valore'][:365].describe(),
                        d2000pm10['Valore'][1176:].describe(), d2000pm10['Valore'][811:1176].describe()],axis=1)
descrittive.columns=["2021","2020","2019","2018","2017","2016","2015","2014","2013","2012","2011","2010","2009","2008","2007",
                     "2006","2005","2004","2003","2002","2001","2000","1999"]
descrittive = descrittive.transpose()
descrittive
# Out:
#       count       mean        std        min        25%        50%        75%  \
# 2021  365.0  28.430239  16.189614   6.885246  16.777778  23.203077  36.290323
# 2020  366.0  28.703364  17.345674   6.056604  15.436649  23.206349  38.666591
# 2019  365.0  27.657012  14.897253   5.132075  17.377049  23.542373  33.295082
# 2018  365.0  29.281348  14.168893   6.303571  18.750000  25.967742  36.714286
# 2017  365.0  34.118531  22.753882   6.620690  18.017241  26.672131  44.688525
# 2016  366.0  30.211258  18.547782   5.909091  17.677083  24.830594  35.752855
# 2015  364.0  34.302640  18.525027   7.414286  20.125143  28.866901  45.785847
# 2014  365.0  29.291352  16.149527   7.368421  17.386667  25.028986  36.702703
# 2013  365.0  32.415382  18.396430   6.455882  19.450704  27.675325  40.565789
# 2012  366.0  35.897382  21.745711   7.900000  21.543720  29.527027  45.740680
# 2011  365.0  38.659002  21.574162   6.246154  22.080000  33.094595  49.943662
# ...

# %% [markdown]
# Problemino, nel 2015 il 1 gennaio non c'è stata una rilevazione valida di pm10 in lombardia, idea di soluzione per le correlazioni: leviamo da tutti il primo gennaio, inoltre leviamo i 29 febbraio per fare la matrice di correlazione

# %% [markdown]
# Matrice di correlazione relativa alle misurazioni di pm10 nei vari anni

# %%
df_corr = pd.DataFrame()
df_corr["2021"] = pm10_2021_corr
df_corr["2020"] = pm10_2020_corr
df_corr["2019"] = pm10_2019_corr
df_corr["2018"] = pm10_2018_corr
df_corr["2017"] = pm10_2017_corr
df_corr["2016"] = pm10_2016_corr
df_corr["2015"] = pm10_2015_corr
df_corr["2014"] = pm10_2014_corr
df_corr["2013"] = pm10_2013_corr
df_corr["2012"] = pm10_2012_corr
df_corr["2011"] = pm10_2011_corr
df_corr["2010"] = pm10_2010_corr
df_corr["2009"] = pm10_2009_corr
df_corr["2008"] = pm10_2008_corr
df_corr["2007"] = pm10_2007_corr
df_corr["2006"] = pm10_2006_corr
df_corr["2005"] = pm10_2005_corr
df_corr["2004"] = pm10_2004_corr
df_corr["2003"] = pm10_2003_corr
df_corr["2002"] = pm10_2002_corr
df_corr["2001"] = pm10_2001_corr
df_corr["2000"] = pm10_2000_corr
df_corr["1999"] = pm10_1999_corr
import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly PM10 time series')
plt.show()

# %% [markdown]
# Matrice di correlazione relativa alle misurazioni dei vari inquinanti nel 2021

# %%
pm10_2021_plot.index = range(len(pm10_2021_plot))
BiAz_2021_plot.index = range(len(BiAz_2021_plot))
OsAz_2021_plot.index = range(len(OsAz_2021_plot))
CO_2021_plot.index = range(len(CO_2021_plot))
O3_2021_plot.index = range(len(O3_2021_plot))
PM2p5_2021_plot.index = range(len(PM2p5_2021_plot))

# %%
df_corr_2021 = pd.DataFrame()
df_corr_2021["PM10"] = pm10_2021_plot
df_corr_2021["NO2"] = BiAz_2021_plot
df_corr_2021["NO"] = OsAz_2021_plot
df_corr_2021["CO"] = CO_2021_plot
df_corr_2021["O3"] = O3_2021_plot
df_corr_2021["PM2.5"] = PM2p5_2021_plot



rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr_2021.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=-1, vmax=1, center=0, cmap="RdBu_r").set(title='Correlation matrix between pollutants in 2021')
plt.show()

# %% [markdown]
# Confronto Grafico tra serie storiche di PM10

# %%
plt.plot(pm10_2019_corr,  label = "2019", color='lawngreen')
plt.plot(pm10_1999_corr, label = "1999", color='turquoise')
plt.title("Comparison between PM10 measurements in 1999 and 2019")
plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %%
plt.plot(pm10_2010_corr,  label = "2010", color='lawngreen')
plt.plot(pm10_2006_corr, label = "2006", color='turquoise')
plt.title("Comparison between PM10 measurements in 2006 and 2010")
plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %%
plt.plot(pm10_2018_corr, label = "2018", color='lawngreen')
plt.plot(pm10_2014_corr, label = "2014", color='turquoise')
plt.title("Comparison between PM10 measurements in 2014 and 2018")
plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %% [markdown]
# Distribuzione rilevazioni inquinanti 2021

# %%
sn.distplot(pm10_2021_plot, axlabel='Pm10 in µg/m3').set(title='Histogram of PM10 averages values in 2021')
plt.axvline(x=50, color='red',linestyle='-',lw=2, label='NO2 daily threshold')
plt.legend()
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.distplot(BiAz_2021_plot, axlabel='NO2 in µg/m3').set(title='Histogram of NO2 averages values in 2021')
plt.axvline(x=50, color='red', linestyle='-', lw=2, label='NO2 daily threshold')
plt.legend()
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.distplot(OsAz_2021_plot, axlabel='NO in µg/m3').set(title='Histogram of NO averages values in 2021')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Histogram of NO averages values in 2021')]

# %%
sn.distplot(CO_2021_plot, axlabel='CO in mg/m3').set(title='Histogram of CO averages values in 2021')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Histogram of CO averages values in 2021')]

# %%
sn.distplot(O3_2021_plot, axlabel='O3 in µg/m³').set(title='Histogram of O3 averages values in 2021')
plt.axvline(x=120, color='red', linestyle='-', lw=2, label='O3 daily threshold')
plt.legend()
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.distplot(PM2p5_2021_plot, axlabel='PM2.5 in µg/m³').set(title='Histogram of PM2.5 averages values in 2021')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Histogram of PM2.5 averages values in 2021')]

# %%
sn.distplot(d2021pm10['Valore'], hist=False, axlabel='PM10 in µg/m³', color = "mediumblue", label="2021").set(title='Histogram of PM10 average values between il 1999 e il 2021')
sn.distplot(d2019pm10['Valore'], hist=False, axlabel='PM10 in µg/m³', color = "lawngreen", label="2019")
sn.distplot(d2015pm10['Valore'], hist=False, axlabel='PM10 in µg/m³', color = "turquoise", label="2015")
sn.distplot(d2011pm10['Valore'], hist=False, axlabel='PM10 in µg/m³', color = "pink", label="2011")
sn.distplot(d2007pm10['Valore'][731:], hist=False, axlabel='PM10 in µg/m³', color = "gold", label="2007")
sn.distplot(d2004pm10['Valore'][731:1095], hist=False, axlabel='PM10 in µg/m³', color = "red", label="2003")
sn.distplot(d2000pm10['Valore'][812:1176], hist=False, axlabel='PM10 in µg/m³', color = "m", label="1999")
plt.axvline(x=50, color='grey', linestyle='-', lw=2, label='PM10 daily threshold')
plt.legend() 
plt.show()
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Distribuzione rilevazioni PM10 negli anni

# %% [markdown]
# Serie Storiche Orarie, indagare la stagionalità oraria

# %%
d2021NO2h = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="Biossido di Azoto")], how="inner")
d2021NO2h = d2021NO2h[['Data','Valore']]
for i in range(len(d2021NO2h)):
    d2021NO2h['Data'][i]= d2021NO2h['Data'][i].hour
d2021NO2h = d2021NO2h.groupby(["Data"]).mean()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/3633931644.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021NO2h['Data'][i]= d2021NO2h['Data'][i].hour
#          Valore
# Data
# 0     25.836909
# 1     23.696273
# 2     22.051719
# 3     20.898649
# 4     20.433927
# 5     21.508167
# 6     24.925793
# 7     29.023089
# 8     30.873225
# 9     29.628407
# 10    27.169248
# 11    24.955137
# 12    22.943741
# 13    21.379951
# 14    20.632329
# 15    20.701041
# 16    21.794277
# 17    24.263606
# 18    27.804976
# 19    31.217268
# 20    32.867123
# 21    32.056434
# 22    30.252749
# 23    28.147297

# %%
d2021NO2h_plot = d2021NO2h["Valore"]
plt.plot(d2021NO2h_plot, marker='o')
plt.title("2021 average measurement of NO2 in Lombardy")
plt.ylabel("concentration in µg/m3")
plt.xlabel("Hour")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='NO2 daily threshold')
# Out:
# Text(0.5, 0, 'Hour')

# %%
d2021O3h = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[(stazioni['NomeTipoSensore']=="Ozono")], how="inner")
d2021O3h = d2021O3h[['Data','Valore']]
for i in range(len(d2021O3h)):
    d2021O3h['Data'][i]= d2021O3h['Data'][i].hour
d2021O3h = d2021O3h.groupby(["Data"]).mean()
# Out:
# C:\Users\stefa\AppData\Local\Temp/ipykernel_1712/4081861105.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2021O3h['Data'][i]= d2021O3h['Data'][i].hour
#          Valore
# Data
# 0     40.657346
# 1     39.409503
# 2     38.255724
# 3     37.142880
# 4     35.707923
# 5     33.372129
# 6     29.963489
# 7     28.128678
# 8     30.832526
# 9     37.829302
# 10    46.597037
# 11    55.556779
# 12    63.944140
# 13    70.829879
# 14    75.525647
# 15    78.183633
# 16    78.264776
# 17    75.367633
# 18    69.622481
# 19    61.897488
# 20    54.117503
# 21    48.425553
# 22    44.815757
# 23    42.320723

# %%
d2021O3h_plot = d2021O3h["Valore"]
plt.plot(d2021O3h, marker='o')
plt.title("2021 average measurement of O3 in Lombardy")
plt.ylabel("concentration in µg/m3")
plt.xlabel("Hour")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='NO2 daily threshold')
# Out:
# Text(0.5, 0, 'Hour')

# %%
sn.distplot( d2019pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2019')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2019')]

# %%
sn.distplot(d2018pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2018')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2018')]

# %%
sn.distplot(d2017pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2017')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2017')]

# %%
sn.distplot(d2016pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2016')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2016')]

# %%
sn.distplot(d2015pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2015')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2015')]

# %%
sn.distplot(d2014pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2014')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2014')]

# %%
sn.distplot(d2013pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2013')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2013')]

# %%
sn.distplot(d2012pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2012')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2012')]

# %%
sn.distplot(d2011pm10['Valore'], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2011')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2011')]

# %%
sn.distplot(d2010pm10['Valore'][732:], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2010')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2010')]

# %%
sn.distplot(d2010pm10['Valore'][367:731], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2009')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2009')]

# %%
sn.distplot(pd.concat([d2010pm10['Valore'][1:59],d2010pm10['Valore'][60:366]]), axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2008')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2008')]

# %%
sn.distplot(d2007pm10['Valore'][731:], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2007')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2007')]

# %%
sn.distplot(d2007pm10['Valore'][366:730], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2006')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2006')]

# %%
sn.distplot(d2007pm10['Valore'][1:365], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2005')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2005')]

# %%
sn.distplot(pd.concat([d2004pm10['Valore'][1096:1154],d2004pm10['Valore'][1155:]]), axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2004')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2004')]

# %%
sn.distplot(d2004pm10['Valore'][731:1095], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2003')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2003')]

# %%
sn.distplot(d2004pm10['Valore'][366:730], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2002')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2002')]

# %%
sn.distplot(d2004pm10['Valore'][1:365], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2001')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2001')]

# %%
sn.distplot(pd.concat([d2000pm10['Valore'][1177:1235],d2000pm10['Valore'][1236:]]), axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 2000')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 2000')]

# %%
sn.distplot(d2000pm10['Valore'][812:1176], axlabel='PM10 in µg/m³').set(title='Istogramma dei valori medi di PM10 riscontrati nel 1999')
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Istogramma dei valori medi di PM10 riscontrati nel 1999')]
