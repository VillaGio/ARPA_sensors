# %%
import matplotlib.pyplot as plt
import seaborn as sn
from matplotlib import rcParams
import pandas as pd
import numpy as np

data2012 = pd.read_pickle('df_meteo_2012.h5')
data2013 = pd.read_pickle('df_meteo_2013.h5')
data2014 = pd.read_pickle('df_meteo_2014.h5')
data2015 = pd.read_pickle('df_meteo_2015.h5')
data2016 = pd.read_pickle('df_meteo_2016.h5')
data2017 = pd.read_pickle('df_meteo_2017.h5')
data2018 = pd.read_pickle('df_meteo_2018.h5')
data2019 = pd.read_pickle('df_meteo_2019.h5')
data2020 = pd.read_pickle('df_meteo_2020.h5')
data2021 = pd.read_pickle('df_meteo_2021.h5')
stazioni = pd.read_pickle('stazioni.h5')

# %%
data2021 = data2021.reset_index()
data2021 = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')

# %%
data2021['Data'] = pd.to_datetime(data2021['Data'], format = "%Y %m %d")
data2021.sort_values(by=['Data'])
#data2021=data2021[data2021['Valore']>0]
data2021['Valore']=data2021['Valore']/144
grouped2021 = data2021.groupby(["Data"]).mean()
rain_2021_plot = grouped2021["Valore"]
plt.plot(rain_2021_plot, marker='o')
plt.title("2021 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2020 = data2020.reset_index()
data2020 = pd.merge(left=data2020[data2020['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2020['Data'] = pd.to_datetime(data2020['Data'], format = "%Y %m %d")
data2020.sort_values(by=['Data'])
#data2020=data2020[data2020['Valore']>0]
data2020['Valore']=data2020['Valore']/144
grouped2020 = data2020.groupby(["Data"]).mean()
rain_2020_plot = grouped2020["Valore"]
plt.plot(rain_2020_plot, marker='o')
plt.title("2020 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2019 = data2019.reset_index()
data2019 = pd.merge(left=data2019[data2019['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2019['Data'] = pd.to_datetime(data2019['Data'], format = "%Y %m %d")
data2019.sort_values(by=['Data'])
#data2019=data2019[data2019['Valore']>0]
data2019['Valore']=data2019['Valore']/144
grouped2019 = data2019.groupby(["Data"]).mean()
rain_2019_plot = grouped2019["Valore"]
plt.plot(rain_2019_plot, marker='o')
plt.title("2019 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2018 = data2018.reset_index()
data2018 = pd.merge(left=data2018[data2018['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2018['Data'] = pd.to_datetime(data2018['Data'], format = "%Y %m %d")
data2018.sort_values(by=['Data'])
#data2018=data2018[data2018['Valore']>0]
data2018['Valore']=data2018['Valore']/144
grouped2018 = data2018.groupby(["Data"]).mean()
rain_2018_plot = grouped2018["Valore"]
plt.plot(rain_2018_plot, marker='o')
plt.title("2018 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2017 = data2017.reset_index()
data2017 = pd.merge(left=data2017[data2017['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2017['Data'] = pd.to_datetime(data2017['Data'], format = "%Y %m %d")
data2017.sort_values(by=['Data'])
#data2017=data2017[data2017['Valore']>0]
data2017['Valore']=data2017['Valore']/144
grouped2017 = data2017.groupby(["Data"]).mean()
rain_2017_plot = grouped2017["Valore"]
plt.plot(rain_2017_plot, marker='o')
plt.title("2017 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2016 = data2016.reset_index()
data2016 = pd.merge(left=data2016[data2016['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2016['Data'] = pd.to_datetime(data2016['Data'], format = "%Y %m %d")
data2016.sort_values(by=['Data'])
#data2016=data2016[data2016['Valore']>0]
data2016['Valore']=data2016['Valore']/144
grouped2016 = data2016.groupby(["Data"]).mean()
rain_2016_plot = grouped2016["Valore"]
plt.plot(rain_2016_plot, marker='o')
plt.title("2016 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2015 = data2015.reset_index()
data2015 = pd.merge(left=data2015[data2015['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2015['Data'] = pd.to_datetime(data2015['Data'], format = "%Y %m %d")
data2015.sort_values(by=['Data'])
#data2015=data2015[data2015['Valore']>0]
data2015['Valore']=data2015['Valore']/144
grouped2015 = data2015.groupby(["Data"]).mean()
rain_2015_plot = grouped2015["Valore"]
plt.plot(rain_2015_plot, marker='o')
plt.title("2015 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2014 = data2014.reset_index()
data2014 = pd.merge(left=data2014[data2014['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2014['Data'] = pd.to_datetime(data2014['Data'], format = "%Y %m %d")
data2014.sort_values(by=['Data'])
#data2014=data2014[data2014['Valore']>0]
data2014['Valore']=data2014['Valore']/144
grouped2014 = data2014.groupby(["Data"]).mean()
rain_2014_plot = grouped2014["Valore"]
plt.plot(rain_2014_plot, marker='o')
plt.title("2014 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2013 = data2013.reset_index()
data2013 = pd.merge(left=data2013[data2013['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2013['Data'] = pd.to_datetime(data2013['Data'], format = "%Y %m %d")
data2013.sort_values(by=['Data'])
#data2013=data2013[data2013['Valore']>0]
data2013['Valore']=data2013['Valore']/144
grouped2013 = data2013.groupby(["Data"]).mean()
rain_2013_plot = grouped2013["Valore"]
plt.plot(rain_2013_plot, marker='o')
plt.title("2013 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
data2012 = data2012.reset_index()
data2012 = pd.merge(left=data2012[data2012['Valore']>0], right=stazioni[stazioni['tipologia']=="Velocità Vento"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2012['Data'] = pd.to_datetime(data2012['Data'], format = "%Y %m %d")
data2012.sort_values(by=['Data'])
data2012=data2012[data2012['Valore']<10000]
data2012['Valore']=data2012['Valore']/144
grouped2012 = data2012.groupby(["Data"]).mean()
rain_2012_plot = grouped2012["Valore"]
plt.plot(rain_2012_plot, marker='o')
plt.title("2012 average measurement of wind speed in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %% [markdown]
# Boxplot

# %%
lista=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([grouped2012['Valore'][:365], grouped2012['Valore'][365:], grouped2013['Valore'], grouped2014['Valore'],
             grouped2015['Valore'], grouped2016['Valore'], grouped2017['Valore'], grouped2018['Valore'], grouped2019['Valore'],
             grouped2020['Valore'], grouped2021['Valore']], positions = lista, patch_artist = True)

plt.title("Boxplots of wind speed measurements by year")
#plt.hlines(y=50, xmin=2011, xmax=2021, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("Year")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %% [markdown]
# Statistiche descrittive

# %%
descrittive = pd.concat([grouped2021['Valore'].describe(),grouped2020['Valore'].describe(), grouped2019['Valore'].describe(),
                        grouped2018['Valore'].describe(), grouped2017['Valore'].describe(), grouped2016['Valore'].describe(),
                        grouped2015['Valore'].describe(), grouped2014['Valore'].describe(), grouped2013['Valore'].describe(),
                        grouped2012['Valore'][365:].describe(), grouped2012['Valore'][:365].describe()],axis=1)
descrittive.columns=["2021","2020","2019","2018","2017","2016","2015","2014","2013","2012","2011"]
descrittive = descrittive.transpose()
descrittive.drop(columns='count')
# Out:
#           mean       std       min       25%       50%       75%        max
# 2021  4.253713  1.211456  1.798539  3.398382  4.051558  4.872264  10.194855
# 2020  4.201531  1.402701  2.045779  3.232164  4.013696  4.748731  11.780259
# 2019  4.584823  1.520142  2.386761  3.576940  4.209307  5.225577  11.383834
# 2018  4.365380  1.221615  1.995231  3.511640  4.247543  4.846316   9.633885
# 2017  4.676498  1.510838  1.204794  3.706663  4.450946  5.366520  12.084538
# 2016  4.394063  1.368215  1.962562  3.450830  4.110835  5.049132  10.509296
# 2015  4.804484  1.587182  2.250514  3.767627  4.645403  5.494410  15.248498
# 2014  3.901922  1.357788  2.001300  3.107078  3.570065  4.418403  14.195240
# 2013  4.563088  1.524314  2.194017  3.623759  4.212289  5.042265  12.320985
# 2012  3.716812  1.593172  0.609491  2.798163  3.735105  4.626418  10.756379
# 2011  2.000803  0.904829  0.584132  1.287693  1.864722  2.494631   5.823531

# %% [markdown]
# correlation matrix

# %%
df_corr = pd.DataFrame()

appo = grouped2021['Valore']
appo.index = range(len(appo))
df_corr["2021"] = appo

appo = pd.concat([grouped2020['Valore'][:59],grouped2020['Valore'][60:]])
appo.index = range(len(appo))
df_corr["2020"] = appo

appo = grouped2019['Valore']
appo.index = range(len(appo))
df_corr["2019"] = appo

appo = grouped2018['Valore']
appo.index = range(len(appo))
df_corr["2018"] = appo

appo = grouped2017['Valore']
appo.index = range(len(appo))
df_corr["2017"] = appo

appo = pd.concat([grouped2016['Valore'][:59],grouped2016['Valore'][60:]])
appo.index = range(len(appo))
df_corr["2016"] = appo

appo = grouped2015['Valore']
appo.index = range(len(appo))
df_corr["2015"] = appo

appo = grouped2014['Valore']
appo.index = range(len(appo))
df_corr["2014"] = appo

appo = grouped2013['Valore']
appo.index = range(len(appo))
df_corr["2013"] = appo

appo = pd.concat([grouped2012['Valore'][366:424],grouped2012['Valore'][425:]])
appo.index = range(len(appo))
df_corr["2012"] = appo

appo = grouped2012['Valore'][:365]
appo.index = range(len(appo))
df_corr["2011"] = appo

import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly wind speed time series')
plt.show()

# %% [markdown]
# Confronto tra serie storiche

# %%
plt.plot(df_corr["2021"],  label = "2021", color='lawngreen')
plt.plot(df_corr["2011"], label = "2011", color='turquoise')
plt.title("Comparison between wind speed measurements in 2011 and 2021")
#plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %%
plt.plot(df_corr["2018"],  label = "2018", color='lawngreen')
plt.plot(df_corr["2016"], label = "2016", color='turquoise')
plt.title("Comparison between wind speed measurements in 2016 and 2018")
#plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("m/s")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %% [markdown]
# Confronto tra densità

# %%
sn.distplot(df_corr["2021"], hist=False, axlabel='m/s', color = "mediumblue", label="2021").set(title='Histogram of average wind speed values between 2011 and 2021')
sn.distplot(df_corr["2019"], hist=False, axlabel='m/s', color = "lawngreen", label="2019")
sn.distplot(df_corr["2017"], hist=False, axlabel='m/s', color = "turquoise", label="2017")
sn.distplot(df_corr["2015"], hist=False, axlabel='m/s', color = "pink", label="2015")
sn.distplot(df_corr["2013"], hist=False, axlabel='m/s', color = "gold", label="2013")
sn.distplot(df_corr["2011"], hist=False, axlabel='m/s', color = "red", label="2011")
#plt.axvline(x=50, color='grey', linestyle='-', lw=2, label='PM10 daily threshold')
#plt.xlim(-5, 60)
plt.legend() 
plt.show()
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# scrittura csv per mappe

# %%
data2021.to_csv('vento2021.csv')
data2019.to_csv('vento2019.csv')
data2017.to_csv('vento2017.csv')
data2015.to_csv('vento2015.csv')
data2013.to_csv('vento2013.csv')
data2012[data2012['Data']<'2012-01-01'].to_csv('vento2011.csv')
