# %% [markdown]
# # Boxplot, matrici di correlazione e densità degli altri inquinanti

# %%
import matplotlib.pyplot as plt
import seaborn as sn
from matplotlib import rcParams
import pandas as pd
import numpy as np

#NO2 = pd.read_csv('serie_NO2.csv')
#NO = pd.read_csv('serie_NO.csv')
#O3 = pd.read_csv('serie_O3.csv')
#CO = pd.read_csv('serie_CO_2001_2021.csv')
pm2p5 = pd.read_csv('serie_pm2p5.csv')

# %%
stazioni=pd.read_csv('Stazioni_qualit__dell_aria.csv')
stazioni.head()

# %% [markdown]
# ## NO2

# %%
NO2_2021_corr = NO2[NO2['Anno']==2021]['Valore']
NO2_2021_corr.index = range(len(NO2_2021_corr))
NO2_2020_corr = NO2[NO2['Anno']==2020]['Valore']
NO2_2020_corr.index = range(len(NO2_2020_corr))
NO2_2019_corr = NO2[NO2['Anno']==2019]['Valore']
NO2_2019_corr.index = range(len(NO2_2019_corr))
NO2_2018_corr = NO2[NO2['Anno']==2018]['Valore']
NO2_2018_corr.index = range(len(NO2_2018_corr))
NO2_2017_corr = NO2[NO2['Anno']==2017]['Valore']
NO2_2017_corr.index = range(len(NO2_2017_corr))
NO2_2016_corr = NO2[NO2['Anno']==2016]['Valore']
NO2_2016_corr.index = range(len(NO2_2016_corr))
NO2_2015_corr = NO2[NO2['Anno']==2015]['Valore']
NO2_2015_corr.index = range(len(NO2_2015_corr))
NO2_2014_corr = NO2[NO2['Anno']==2014]['Valore']
NO2_2014_corr.index = range(len(NO2_2014_corr))
NO2_2013_corr = NO2[NO2['Anno']==2013]['Valore']
NO2_2013_corr.index = range(len(NO2_2013_corr))
NO2_2012_corr = NO2[NO2['Anno']==2012]['Valore']
NO2_2012_corr.index = range(len(NO2_2012_corr))
NO2_2011_corr = NO2[NO2['Anno']==2011]['Valore']
NO2_2011_corr.index = range(len(NO2_2011_corr))
NO2_2010_corr = NO2[NO2['Anno']==2010]['Valore']
NO2_2010_corr.index = range(len(NO2_2010_corr))
NO2_2009_corr = NO2[NO2['Anno']==2009]['Valore']
NO2_2009_corr.index = range(len(NO2_2009_corr))
NO2_2008_corr = NO2[NO2['Anno']==2008]['Valore']
NO2_2008_corr.index = range(len(NO2_2008_corr))
NO2_2007_corr = NO2[NO2['Anno']==2007]['Valore']
NO2_2007_corr.index = range(len(NO2_2007_corr))
NO2_2006_corr = NO2[NO2['Anno']==2006]['Valore']
NO2_2006_corr.index = range(len(NO2_2006_corr))
NO2_2005_corr = NO2[NO2['Anno']==2005]['Valore']
NO2_2005_corr.index = range(len(NO2_2005_corr))
NO2_2004_corr = NO2[NO2['Anno']==2004]['Valore']
NO2_2004_corr.index = range(len(NO2_2004_corr))
NO2_2003_corr = NO2[NO2['Anno']==2003]['Valore']
NO2_2003_corr.index = range(len(NO2_2003_corr))
NO2_2002_corr = NO2[NO2['Anno']==2002]['Valore']
NO2_2002_corr.index = range(len(NO2_2002_corr))
NO2_2001_corr = NO2[NO2['Anno']==2001]['Valore']
NO2_2001_corr.index = range(len(NO2_2001_corr))
NO2_2000_corr = NO2[NO2['Anno']==2000]['Valore']
NO2_2000_corr.index = range(len(NO2_2000_corr))
NO2_1999_corr = NO2[NO2['Anno']==1999]['Valore']
NO2_1999_corr.index = range(len(NO2_1999_corr))

# %%
lista=[1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([NO2_1999_corr, NO2_2000_corr,  NO2_2001_corr,  NO2_2002_corr,  NO2_2003_corr,
             NO2_2004_corr, NO2_2005_corr,  NO2_2006_corr,  NO2_2007_corr,  NO2_2008_corr,
             NO2_2009_corr, NO2_2010_corr,  NO2_2011_corr,  NO2_2012_corr,  NO2_2013_corr,
             NO2_2014_corr, NO2_2015_corr,  NO2_2016_corr,  NO2_2017_corr,  NO2_2018_corr,
             NO2_2019_corr, NO2_2020_corr,  NO2_2021_corr], positions = lista, patch_artist = True)

plt.title("Boxplots of NO2 measurements by year")
plt.hlines(y=50, xmin=1999, xmax=2021, colors='red', linestyles='-', lw=2, label='NO2 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Year")
#plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()

# %%
df_corr = pd.DataFrame()
df_corr["2021"] = NO2_2021_corr
df_corr["2020"] = NO2_2020_corr
df_corr["2019"] = NO2_2019_corr
df_corr["2018"] = NO2_2018_corr
df_corr["2017"] = NO2_2017_corr
df_corr["2016"] = NO2_2016_corr
df_corr["2015"] = NO2_2015_corr
df_corr["2014"] = NO2_2014_corr
df_corr["2013"] = NO2_2013_corr
df_corr["2012"] = NO2_2012_corr
df_corr["2011"] = NO2_2011_corr
df_corr["2010"] = NO2_2010_corr
df_corr["2009"] = NO2_2009_corr
df_corr["2008"] = NO2_2008_corr
df_corr["2007"] = NO2_2007_corr
df_corr["2006"] = NO2_2006_corr
df_corr["2005"] = NO2_2005_corr
df_corr["2004"] = NO2_2004_corr
df_corr["2003"] = NO2_2003_corr
df_corr["2002"] = NO2_2002_corr
df_corr["2001"] = NO2_2001_corr
df_corr["2000"] = NO2_2000_corr
df_corr["1999"] = NO2_1999_corr
import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly NO2 time series')
plt.show()

# %%
sn.distplot(df_corr["2021"], hist=False, axlabel='NO2 in µg/m³', color = "mediumblue", label="2021").set(title='Histogram of NO2 average values between il 1999 e il 2021')
sn.distplot(df_corr["2019"], hist=False, axlabel='NO2 in µg/m³', color = "lawngreen", label="2019")
sn.distplot(df_corr["2015"], hist=False, axlabel='NO2 in µg/m³', color = "turquoise", label="2015")
sn.distplot(df_corr["2011"], hist=False, axlabel='NO2 in µg/m³', color = "pink", label="2011")
sn.distplot(df_corr["2007"], hist=False, axlabel='NO2 in µg/m³', color = "gold", label="2007")
sn.distplot(df_corr["2003"], hist=False, axlabel='NO2 in µg/m³', color = "red", label="2003")
sn.distplot(df_corr["1999"], hist=False, axlabel='NO2 in µg/m³', color = "m", label="1999")
plt.axvline(x=50, color='grey', linestyle='-', lw=2, label='NO2 daily threshold')
plt.legend() 
plt.show()

# %% [markdown]
# ## NO

# %%
NO_2021_corr = NO[NO['Anno']==2021]['Valore']
NO_2021_corr.index = range(len(NO_2021_corr))
NO_2020_corr = NO[NO['Anno']==2020]['Valore']
NO_2020_corr.index = range(len(NO_2020_corr))
NO_2019_corr = NO[NO['Anno']==2019]['Valore']
NO_2019_corr.index = range(len(NO_2019_corr))
NO_2018_corr = NO[NO['Anno']==2018]['Valore']
NO_2018_corr.index = range(len(NO_2018_corr))
NO_2017_corr = NO[NO['Anno']==2017]['Valore']
NO_2017_corr.index = range(len(NO_2017_corr))
NO_2016_corr = NO[NO['Anno']==2016]['Valore']
NO_2016_corr.index = range(len(NO_2016_corr))
NO_2015_corr = NO[NO['Anno']==2015]['Valore']
NO_2015_corr.index = range(len(NO_2015_corr))
NO_2014_corr = NO[NO['Anno']==2014]['Valore']
NO_2014_corr.index = range(len(NO_2014_corr))
NO_2013_corr = NO[NO['Anno']==2013]['Valore']
NO_2013_corr.index = range(len(NO_2013_corr))
NO_2012_corr = NO[NO['Anno']==2012]['Valore']
NO_2012_corr.index = range(len(NO_2012_corr))
NO_2011_corr = NO[NO['Anno']==2011]['Valore']
NO_2011_corr.index = range(len(NO_2011_corr))
NO_2010_corr = NO[NO['Anno']==2010]['Valore']
NO_2010_corr.index = range(len(NO_2010_corr))
NO_2009_corr = NO[NO['Anno']==2009]['Valore']
NO_2009_corr.index = range(len(NO_2009_corr))
NO_2008_corr = NO[NO['Anno']==2008]['Valore']
NO_2008_corr.index = range(len(NO_2008_corr))
NO_2007_corr = NO[NO['Anno']==2007]['Valore']
NO_2007_corr.index = range(len(NO_2007_corr))
NO_2006_corr = NO[NO['Anno']==2006]['Valore']
NO_2006_corr.index = range(len(NO_2006_corr))
NO_2005_corr = NO[NO['Anno']==2005]['Valore']
NO_2005_corr.index = range(len(NO_2005_corr))
NO_2004_corr = NO[NO['Anno']==2004]['Valore']
NO_2004_corr.index = range(len(NO_2004_corr))
NO_2003_corr = NO[NO['Anno']==2003]['Valore']
NO_2003_corr.index = range(len(NO_2003_corr))
NO_2002_corr = NO[NO['Anno']==2002]['Valore']
NO_2002_corr.index = range(len(NO_2002_corr))
NO_2001_corr = NO[NO['Anno']==2001]['Valore']
NO_2001_corr.index = range(len(NO_2001_corr))
NO_2000_corr = NO[NO['Anno']==2000]['Valore']
NO_2000_corr.index = range(len(NO_2000_corr))
NO_1999_corr = NO[NO['Anno']==1999]['Valore']
NO_1999_corr.index = range(len(NO_1999_corr))

# %%
lista=[1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([NO_1999_corr, NO_2000_corr,  NO_2001_corr,  NO_2002_corr,  NO_2003_corr,
             NO_2004_corr, NO_2005_corr,  NO_2006_corr,  NO_2007_corr,  NO_2008_corr,
             NO_2009_corr, NO_2010_corr,  NO_2011_corr,  NO_2012_corr,  NO_2013_corr,
             NO_2014_corr, NO_2015_corr,  NO_2016_corr,  NO_2017_corr,  NO_2018_corr,
             NO_2019_corr, NO_2020_corr,  NO_2021_corr], positions = lista, patch_artist = True)

plt.title("Boxplots of NO measurements by year")
#plt.hlines(y=50, xmin=1999, xmax=2021, colors='red', linestyles='-', lw=2, label='NO daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Year")
#plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
df_corr = pd.DataFrame()
df_corr["2021"] = NO_2021_corr
df_corr["2020"] = NO_2020_corr
df_corr["2019"] = NO_2019_corr
df_corr["2018"] = NO_2018_corr
df_corr["2017"] = NO_2017_corr
df_corr["2016"] = NO_2016_corr
df_corr["2015"] = NO_2015_corr
df_corr["2014"] = NO_2014_corr
df_corr["2013"] = NO_2013_corr
df_corr["2012"] = NO_2012_corr
df_corr["2011"] = NO_2011_corr
df_corr["2010"] = NO_2010_corr
df_corr["2009"] = NO_2009_corr
df_corr["2008"] = NO_2008_corr
df_corr["2007"] = NO_2007_corr
df_corr["2006"] = NO_2006_corr
df_corr["2005"] = NO_2005_corr
df_corr["2004"] = NO_2004_corr
df_corr["2003"] = NO_2003_corr
df_corr["2002"] = NO_2002_corr
df_corr["2001"] = NO_2001_corr
df_corr["2000"] = NO_2000_corr
df_corr["1999"] = NO_1999_corr
import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly NO time series')
plt.show()

# %%
sn.distplot(df_corr["2021"], hist=False, axlabel='NO in µg/m³', color = "mediumblue", label="2021").set(title='Histogram of NO average values between il 1999 e il 2021')
sn.distplot(df_corr["2019"], hist=False, axlabel='NO in µg/m³', color = "lawngreen", label="2019")
sn.distplot(df_corr["2015"], hist=False, axlabel='NO in µg/m³', color = "turquoise", label="2015")
sn.distplot(df_corr["2011"], hist=False, axlabel='NO in µg/m³', color = "pink", label="2011")
sn.distplot(df_corr["2007"], hist=False, axlabel='NO in µg/m³', color = "gold", label="2007")
sn.distplot(df_corr["2003"], hist=False, axlabel='NO in µg/m³', color = "red", label="2003")
sn.distplot(df_corr["1999"], hist=False, axlabel='NO in µg/m³', color = "m", label="1999")

plt.legend() 
plt.show()

# %% [markdown]
# ## CO

# %%
CO_2021_corr = CO[CO['Anno']==2021]['Valore']
CO_2021_corr.index = range(len(CO_2021_corr))
CO_2020_corr = CO[CO['Anno']==2020]['Valore']
CO_2020_corr.index = range(len(CO_2020_corr))
CO_2019_corr = CO[CO['Anno']==2019]['Valore']
CO_2019_corr.index = range(len(CO_2019_corr))
CO_2018_corr = CO[CO['Anno']==2018]['Valore']
CO_2018_corr.index = range(len(CO_2018_corr))
CO_2017_corr = CO[CO['Anno']==2017]['Valore']
CO_2017_corr.index = range(len(CO_2017_corr))
CO_2016_corr = CO[CO['Anno']==2016]['Valore']
CO_2016_corr.index = range(len(CO_2016_corr))
CO_2015_corr = CO[CO['Anno']==2015]['Valore']
CO_2015_corr.index = range(len(CO_2015_corr))
CO_2014_corr = CO[CO['Anno']==2014]['Valore']
CO_2014_corr.index = range(len(CO_2014_corr))
CO_2013_corr = CO[CO['Anno']==2013]['Valore']
CO_2013_corr.index = range(len(CO_2013_corr))
CO_2012_corr = CO[CO['Anno']==2012]['Valore']
CO_2012_corr.index = range(len(CO_2012_corr))
CO_2011_corr = CO[CO['Anno']==2011]['Valore']
CO_2011_corr.index = range(len(CO_2011_corr))
CO_2010_corr = CO[CO['Anno']==2010]['Valore']
CO_2010_corr.index = range(len(CO_2010_corr))
CO_2009_corr = CO[CO['Anno']==2009]['Valore']
CO_2009_corr.index = range(len(CO_2009_corr))
CO_2008_corr = CO[CO['Anno']==2008]['Valore']
CO_2008_corr.index = range(len(CO_2008_corr))
CO_2007_corr = CO[CO['Anno']==2007]['Valore']
CO_2007_corr.index = range(len(CO_2007_corr))
CO_2006_corr = CO[CO['Anno']==2006]['Valore']
CO_2006_corr.index = range(len(CO_2006_corr))
CO_2005_corr = CO[CO['Anno']==2005]['Valore']
CO_2005_corr.index = range(len(CO_2005_corr))
CO_2004_corr = CO[CO['Anno']==2004]['Valore']
CO_2004_corr.index = range(len(CO_2004_corr))
CO_2003_corr = CO[CO['Anno']==2003]['Valore']
CO_2003_corr.index = range(len(CO_2003_corr))
CO_2002_corr = CO[CO['Anno']==2002]['Valore']
CO_2002_corr.index = range(len(CO_2002_corr))
CO_2001_corr = CO[CO['Anno']==2001]['Valore']
CO_2001_corr.index = range(len(CO_2001_corr))
CO_2000_corr = CO[CO['Anno']==2000]['Valore']
CO_2000_corr.index = range(len(CO_2000_corr))
CO_1999_corr = CO[CO['Anno']==1999]['Valore']
CO_1999_corr.index = range(len(CO_1999_corr))

# %%
lista=[1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([CO_1999_corr, CO_2000_corr,  CO_2001_corr,  CO_2002_corr,  CO_2003_corr,
             CO_2004_corr, CO_2005_corr,  CO_2006_corr,  CO_2007_corr,  CO_2008_corr,
             CO_2009_corr, CO_2010_corr,  CO_2011_corr,  CO_2012_corr,  CO_2013_corr,
             CO_2014_corr, CO_2015_corr,  CO_2016_corr,  CO_2017_corr,  CO_2018_corr,
             CO_2019_corr, CO_2020_corr,  CO_2021_corr], positions = lista, patch_artist = True)

plt.title("Boxplots of CO measurements by year")
#plt.hlines(y=50, xmin=1999, xmax=2021, colors='red', linestyles='-', lw=2, label='CO daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Year")
#plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
df_corr = pd.DataFrame()
df_corr["2021"] = CO_2021_corr
df_corr["2020"] = CO_2020_corr
df_corr["2019"] = CO_2019_corr
df_corr["2018"] = CO_2018_corr
df_corr["2017"] = CO_2017_corr
df_corr["2016"] = CO_2016_corr
df_corr["2015"] = CO_2015_corr
df_corr["2014"] = CO_2014_corr
df_corr["2013"] = CO_2013_corr
df_corr["2012"] = CO_2012_corr
df_corr["2011"] = CO_2011_corr
df_corr["2010"] = CO_2010_corr
df_corr["2009"] = CO_2009_corr
df_corr["2008"] = CO_2008_corr
df_corr["2007"] = CO_2007_corr
df_corr["2006"] = CO_2006_corr
df_corr["2005"] = CO_2005_corr
df_corr["2004"] = CO_2004_corr
df_corr["2003"] = CO_2003_corr
df_corr["2002"] = CO_2002_corr
df_corr["2001"] = CO_2001_corr
df_corr["2000"] = CO_2000_corr
df_corr["1999"] = CO_1999_corr
import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly CO time series')
plt.show()

# %%
sn.distplot(df_corr["2021"], hist=False, axlabel='CO in µg/m³', color = "mediumblue", label="2021").set(title='Histogram of CO average values between il 1999 e il 2021')
sn.distplot(df_corr["2019"], hist=False, axlabel='CO in µg/m³', color = "lawngreen", label="2019")
sn.distplot(df_corr["2015"], hist=False, axlabel='CO in µg/m³', color = "turquoise", label="2015")
sn.distplot(df_corr["2011"], hist=False, axlabel='CO in µg/m³', color = "pink", label="2011")
sn.distplot(df_corr["2007"], hist=False, axlabel='CO in µg/m³', color = "gold", label="2007")
sn.distplot(df_corr["2003"], hist=False, axlabel='CO in µg/m³', color = "red", label="2003")
sn.distplot(df_corr["1999"], hist=False, axlabel='CO in µg/m³', color = "m", label="1999")

plt.legend() 
plt.show()

# %% [markdown]
# ## O3

# %%
O3_2021_O3rr = O3[O3['Anno']==2021]['Valore']
O3_2021_O3rr.index = range(len(O3_2021_O3rr))
O3_2020_O3rr = O3[O3['Anno']==2020]['Valore']
O3_2020_O3rr.index = range(len(O3_2020_O3rr))
O3_2019_O3rr = O3[O3['Anno']==2019]['Valore']
O3_2019_O3rr.index = range(len(O3_2019_O3rr))
O3_2018_O3rr = O3[O3['Anno']==2018]['Valore']
O3_2018_O3rr.index = range(len(O3_2018_O3rr))
O3_2017_O3rr = O3[O3['Anno']==2017]['Valore']
O3_2017_O3rr.index = range(len(O3_2017_O3rr))
O3_2016_O3rr = O3[O3['Anno']==2016]['Valore']
O3_2016_O3rr.index = range(len(O3_2016_O3rr))
O3_2015_O3rr = O3[O3['Anno']==2015]['Valore']
O3_2015_O3rr.index = range(len(O3_2015_O3rr))
O3_2014_O3rr = O3[O3['Anno']==2014]['Valore']
O3_2014_O3rr.index = range(len(O3_2014_O3rr))
O3_2013_O3rr = O3[O3['Anno']==2013]['Valore']
O3_2013_O3rr.index = range(len(O3_2013_O3rr))
O3_2012_O3rr = O3[O3['Anno']==2012]['Valore']
O3_2012_O3rr.index = range(len(O3_2012_O3rr))
O3_2011_O3rr = O3[O3['Anno']==2011]['Valore']
O3_2011_O3rr.index = range(len(O3_2011_O3rr))
O3_2010_O3rr = O3[O3['Anno']==2010]['Valore']
O3_2010_O3rr.index = range(len(O3_2010_O3rr))
O3_2009_O3rr = O3[O3['Anno']==2009]['Valore']
O3_2009_O3rr.index = range(len(O3_2009_O3rr))
O3_2008_O3rr = O3[O3['Anno']==2008]['Valore']
O3_2008_O3rr.index = range(len(O3_2008_O3rr))
O3_2007_O3rr = O3[O3['Anno']==2007]['Valore']
O3_2007_O3rr.index = range(len(O3_2007_O3rr))
O3_2006_O3rr = O3[O3['Anno']==2006]['Valore']
O3_2006_O3rr.index = range(len(O3_2006_O3rr))
O3_2005_O3rr = O3[O3['Anno']==2005]['Valore']
O3_2005_O3rr.index = range(len(O3_2005_O3rr))
O3_2004_O3rr = O3[O3['Anno']==2004]['Valore']
O3_2004_O3rr.index = range(len(O3_2004_O3rr))
O3_2003_O3rr = O3[O3['Anno']==2003]['Valore']
O3_2003_O3rr.index = range(len(O3_2003_O3rr))
O3_2002_O3rr = O3[O3['Anno']==2002]['Valore']
O3_2002_O3rr.index = range(len(O3_2002_O3rr))
O3_2001_O3rr = O3[O3['Anno']==2001]['Valore']
O3_2001_O3rr.index = range(len(O3_2001_O3rr))
O3_2000_O3rr = O3[O3['Anno']==2000]['Valore']
O3_2000_O3rr.index = range(len(O3_2000_O3rr))
O3_1999_O3rr = O3[O3['Anno']==1999]['Valore']
O3_1999_O3rr.index = range(len(O3_1999_O3rr))

# %%
lista=[1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([O3_1999_O3rr, O3_2000_O3rr,  O3_2001_O3rr,  O3_2002_O3rr,  O3_2003_O3rr,
             O3_2004_O3rr, O3_2005_O3rr,  O3_2006_O3rr,  O3_2007_O3rr,  O3_2008_O3rr,
             O3_2009_O3rr, O3_2010_O3rr,  O3_2011_O3rr,  O3_2012_O3rr,  O3_2013_O3rr,
             O3_2014_O3rr, O3_2015_O3rr,  O3_2016_O3rr,  O3_2017_O3rr,  O3_2018_O3rr,
             O3_2019_O3rr, O3_2020_O3rr,  O3_2021_O3rr], positions = lista, patch_artist = True)

plt.title("Boxplots of O3 measurements by year")
plt.hlines(y=120, xmin=1999, xmax=2021, colors='red', linestyles='-', lw=2, label='O3 daily threshold')
plt.ylabel("Concentration in µg/m3")
plt.xlabel("Year")
#plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %%
df_O3rr = pd.DataFrame()
df_O3rr["2021"] = O3_2021_O3rr
df_O3rr["2020"] = O3_2020_O3rr
df_O3rr["2019"] = O3_2019_O3rr
df_O3rr["2018"] = O3_2018_O3rr
df_O3rr["2017"] = O3_2017_O3rr
df_O3rr["2016"] = O3_2016_O3rr
df_O3rr["2015"] = O3_2015_O3rr
df_O3rr["2014"] = O3_2014_O3rr
df_O3rr["2013"] = O3_2013_O3rr
df_O3rr["2012"] = O3_2012_O3rr
df_O3rr["2011"] = O3_2011_O3rr
df_O3rr["2010"] = O3_2010_O3rr
df_O3rr["2009"] = O3_2009_O3rr
df_O3rr["2008"] = O3_2008_O3rr
df_O3rr["2007"] = O3_2007_O3rr
df_O3rr["2006"] = O3_2006_O3rr
df_O3rr["2005"] = O3_2005_O3rr
df_O3rr["2004"] = O3_2004_O3rr
df_O3rr["2003"] = O3_2003_O3rr
df_O3rr["2002"] = O3_2002_O3rr
df_O3rr["2001"] = O3_2001_O3rr
df_O3rr["2000"] = O3_2000_O3rr
df_O3rr["1999"] = O3_1999_O3rr
import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_O3rr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly O3 time series')
plt.show()

# %%
sn.distplot(df_O3rr["2021"], hist=False, axlabel='O3 in µg/m³', color = "mediumblue", label="2021").set(title='Histogram of O3 average values between il 1999 e il 2021')
sn.distplot(df_O3rr["2019"], hist=False, axlabel='O3 in µg/m³', color = "lawngreen", label="2019")
sn.distplot(df_O3rr["2015"], hist=False, axlabel='O3 in µg/m³', color = "turquoise", label="2015")
sn.distplot(df_O3rr["2011"], hist=False, axlabel='O3 in µg/m³', color = "pink", label="2011")
sn.distplot(df_O3rr["2007"], hist=False, axlabel='O3 in µg/m³', color = "gold", label="2007")
sn.distplot(df_O3rr["2003"], hist=False, axlabel='O3 in µg/m³', color = "red", label="2003")
sn.distplot(df_O3rr["1999"], hist=False, axlabel='O3 in µg/m³', color = "m", label="1999")
plt.axvline(x=120, color='grey', linestyle='-', lw=2, label='O3 daily threshold')
plt.legend() 
plt.show()

# %% [markdown]
# ## PM2.5

# %%
pm2p5_2021_corr = pm2p5[pm2p5['Anno']==2021]['Valore']
pm2p5_2021_corr.index = range(len(pm2p5_2021_corr))
pm2p5_2020_corr = pm2p5[pm2p5['Anno']==2020]['Valore']
pm2p5_2020_corr.index = range(len(pm2p5_2020_corr))
pm2p5_2019_corr = pm2p5[pm2p5['Anno']==2019]['Valore']
pm2p5_2019_corr.index = range(len(pm2p5_2019_corr))
pm2p5_2018_corr = pm2p5[pm2p5['Anno']==2018]['Valore']
pm2p5_2018_corr.index = range(len(pm2p5_2018_corr))
pm2p5_2017_corr = pm2p5[pm2p5['Anno']==2017]['Valore']
pm2p5_2017_corr.index = range(len(pm2p5_2017_corr))
pm2p5_2016_corr = pm2p5[pm2p5['Anno']==2016]['Valore']
pm2p5_2016_corr.index = range(len(pm2p5_2016_corr))
pm2p5_2015_corr = pm2p5[pm2p5['Anno']==2015]['Valore']
pm2p5_2015_corr.index = range(len(pm2p5_2015_corr))
pm2p5_2014_corr = pm2p5[pm2p5['Anno']==2014]['Valore']
pm2p5_2014_corr.index = range(len(pm2p5_2014_corr))
pm2p5_2013_corr = pm2p5[pm2p5['Anno']==2013]['Valore']
pm2p5_2013_corr.index = range(len(pm2p5_2013_corr))
pm2p5_2012_corr = pm2p5[pm2p5['Anno']==2012]['Valore']
pm2p5_2012_corr.index = range(len(pm2p5_2012_corr))
pm2p5_2011_corr = pm2p5[pm2p5['Anno']==2011]['Valore']
pm2p5_2011_corr.index = range(len(pm2p5_2011_corr))
pm2p5_2010_corr = pm2p5[pm2p5['Anno']==2010]['Valore']
pm2p5_2010_corr.index = range(len(pm2p5_2010_corr))
pm2p5_2009_corr = pm2p5[pm2p5['Anno']==2009]['Valore']
pm2p5_2009_corr.index = range(len(pm2p5_2009_corr))
pm2p5_2008_corr = pm2p5[pm2p5['Anno']==2008]['Valore']
pm2p5_2008_corr.index = range(len(pm2p5_2008_corr))
pm2p5_2007_corr = pm2p5[pm2p5['Anno']==2007]['Valore']
pm2p5_2007_corr.index = range(len(pm2p5_2007_corr))
pm2p5_2006_corr = pm2p5[pm2p5['Anno']==2006]['Valore']
pm2p5_2006_corr.index = range(len(pm2p5_2006_corr))
pm2p5_2005_corr = pm2p5[pm2p5['Anno']==2005]['Valore']
pm2p5_2005_corr.index = range(len(pm2p5_2005_corr))
pm2p5_2004_corr = pm2p5[pm2p5['Anno']==2004]['Valore']
pm2p5_2004_corr.index = range(len(pm2p5_2004_corr))
pm2p5_2003_corr = pm2p5[pm2p5['Anno']==2003]['Valore']
pm2p5_2003_corr.index = range(len(pm2p5_2003_corr))
pm2p5_2002_corr = pm2p5[pm2p5['Anno']==2002]['Valore']
pm2p5_2002_corr.index = range(len(pm2p5_2002_corr))
pm2p5_2001_corr = pm2p5[pm2p5['Anno']==2001]['Valore']
pm2p5_2001_corr.index = range(len(pm2p5_2001_corr))
pm2p5_2000_corr = pm2p5[pm2p5['Anno']==2000]['Valore']
pm2p5_2000_corr.index = range(len(pm2p5_2000_corr))
pm2p5_1999_corr = pm2p5[pm2p5['Anno']==1999]['Valore']
pm2p5_1999_corr.index = range(len(pm2p5_1999_corr))

# %%
lista=[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([pm2p5_2006_corr,  pm2p5_2007_corr,  pm2p5_2008_corr,
             pm2p5_2009_corr, pm2p5_2010_corr,  pm2p5_2011_corr,  pm2p5_2012_corr,  pm2p5_2013_corr,
             pm2p5_2014_corr, pm2p5_2015_corr,  pm2p5_2016_corr,  pm2p5_2017_corr,  pm2p5_2018_corr,
             pm2p5_2019_corr, pm2p5_2020_corr,  pm2p5_2021_corr], positions = lista, patch_artist = True)

plt.title("Boxplots of pm2p5 measurements by year")
plt.hlines(y=25, xmin=2006, xmax=2021, colors='red', linestyles='-', lw=2, label='pm2p5 daily threshold')
plt.ylabel("concentration in µg/m3")
plt.xlabel("Year")
#plt.rcParams["figure.figsize"] = (15,6)
plt.legend()
plt.show()
# Out:
# C:\Users\User\Miniconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df_corr = pd.DataFrame()
df_corr["2021"] = pm2p5_2021_corr
df_corr["2020"] = pm2p5_2020_corr
df_corr["2019"] = pm2p5_2019_corr
df_corr["2018"] = pm2p5_2018_corr
df_corr["2017"] = pm2p5_2017_corr
df_corr["2016"] = pm2p5_2016_corr
df_corr["2015"] = pm2p5_2015_corr
df_corr["2014"] = pm2p5_2014_corr
df_corr["2013"] = pm2p5_2013_corr
df_corr["2012"] = pm2p5_2012_corr
df_corr["2011"] = pm2p5_2011_corr
df_corr["2010"] = pm2p5_2010_corr
df_corr["2009"] = pm2p5_2009_corr
df_corr["2008"] = pm2p5_2008_corr
df_corr["2007"] = pm2p5_2007_corr
df_corr["2006"] = pm2p5_2006_corr

import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly pm2p5 time series')
plt.show()

# %%
sn.distplot(df_corr["2021"], hist=False, axlabel='pm2p5 in µg/m³', color = "mediumblue", label="2021").set(title='Histogram of pm2.5 average values between il 2006 e il 2021')
sn.distplot(df_corr["2019"], hist=False, axlabel='pm2p5 in µg/m³', color = "lawngreen", label="2019")
sn.distplot(df_corr["2015"], hist=False, axlabel='pm2p5 in µg/m³', color = "turquoise", label="2015")
sn.distplot(df_corr["2011"], hist=False, axlabel='pm2p5 in µg/m³', color = "pink", label="2011")
sn.distplot(df_corr["2006"], hist=False, axlabel='pm2p5 in µg/m³', color = "gold", label="2006")
plt.axvline(x=25, color='grey', linestyle='-', lw=2, label='pm2.5 daily threshold')
plt.legend() 
plt.show()
# Out:
# C:\Users\User\Miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\Miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...
