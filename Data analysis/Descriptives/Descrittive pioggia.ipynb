# %%
import matplotlib.pyplot as plt
import seaborn as sn
from matplotlib import rcParams
import pandas as pd
import numpy as np

data2012 = pd.read_pickle('df_meteo_2012.h5')
data2013 = pd.read_pickle('df_meteo_2013.h5')
data2014 = pd.read_pickle('df_meteo_2014.h5')
data2015 = pd.read_pickle('df_meteo_2015.h5')
data2016 = pd.read_pickle('df_meteo_2016.h5')
data2017 = pd.read_pickle('df_meteo_2017.h5')
data2018 = pd.read_pickle('df_meteo_2018.h5')
data2019 = pd.read_pickle('df_meteo_2019.h5')
data2020 = pd.read_pickle('df_meteo_2020.h5')
data2021 = pd.read_pickle('df_meteo_2021.h5')
stazioni = pd.read_pickle('stazioni.h5')

# %%
data2021 = data2021.reset_index()
data2021 = pd.merge(left=data2021[data2021['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')

# %%
data2021.head()
# Out:
#         Data  IdSensore  Valore  idsensore       tipologia unit_dimisura  \
# 0   2021 1 1          9     1.2          9  Precipitazione            mm
# 1  2021 1 10          9     0.8          9  Precipitazione            mm
# 2  2021 1 14          9     1.2          9  Precipitazione            mm
# 3  2021 1 15          9     1.8          9  Precipitazione            mm
# 4   2021 1 2          9     5.0          9  Precipitazione            mm
#
#    idstazione      nomestazione  quota provincia storico  datastart  \
# 0           3  Sondalo Le Prese    950        SO       N 1987-11-24
# 1           3  Sondalo Le Prese    950        SO       N 1987-11-24
# 2           3  Sondalo Le Prese    950        SO       N 1987-11-24
# 3           3  Sondalo Le Prese    950        SO       N 1987-11-24
# 4           3  Sondalo Le Prese    950        SO       N 1987-11-24
#
#               datastop  cgb_nord  cgb_est       lat        lng  \
# 0  9999-12-31 00:00:00   5133847   604242  46.35017  10.354812
# 1  9999-12-31 00:00:00   5133847   604242  46.35017  10.354812
# 2  9999-12-31 00:00:00   5133847   604242  46.35017  10.354812
# 3  9999-12-31 00:00:00   5133847   604242  46.35017  10.354812
# 4  9999-12-31 00:00:00   5133847   604242  46.35017  10.354812
#
#               coordinate
# 0  (46.35017, 10.354812)
# 1  (46.35017, 10.354812)
# 2  (46.35017, 10.354812)
# 3  (46.35017, 10.354812)
# 4  (46.35017, 10.354812)

# %%
data2021['Data'] = pd.to_datetime(data2021['Data'], format = "%Y %m %d")
data2021.sort_values(by=['Data'])
#data2021=data2021[data2021['Valore']>0]
#data2021['Valore']=data2021['Valore']/10
grouped2021 = data2021.groupby(["Data"]).mean()
rain_2021_plot = grouped2021["Valore"]
plt.plot(rain_2021_plot, marker='o')
plt.title("2021 average measurement of rain in Lombardy")
#plt.hlines(y=50, xmin=18620, xmax=18620+380, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("mm of rain")
plt.xlabel("Date")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %% [markdown]
# Pre-Processing

# %%
data2020 = data2020.reset_index()
data2020 = pd.merge(left=data2020[data2020['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2020['Data'] = pd.to_datetime(data2020['Data'], format = "%Y %m %d")
data2020.sort_values(by=['Data'])
data2020=data2020[data2020['Valore']<1000]

grouped2020 = data2020.groupby(["Data"]).mean()

# %%
data2019 = data2019.reset_index()
data2019 = pd.merge(left=data2019[data2019['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2019['Data'] = pd.to_datetime(data2019['Data'], format = "%Y %m %d")
data2019.sort_values(by=['Data'])
data2019=data2019[data2019['Valore']<1000]

grouped2019 = data2019.groupby(["Data"]).mean()

# %%
data2018 = data2018.reset_index()
data2018 = pd.merge(left=data2018[data2018['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2018['Data'] = pd.to_datetime(data2018['Data'], format = "%Y %m %d")
data2018.sort_values(by=['Data'])
data2018=data2018[data2018['Valore']<1000]

grouped2018 = data2018.groupby(["Data"]).mean()

# %%
data2017 = data2017.reset_index()
data2017 = pd.merge(left=data2017[data2017['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2017['Data'] = pd.to_datetime(data2017['Data'], format = "%Y %m %d")
data2017.sort_values(by=['Data'])
data2017=data2017[data2017['Valore']<1000]

grouped2017 = data2017.groupby(["Data"]).mean()

# %%
data2016 = data2016.reset_index()
data2016 = pd.merge(left=data2016[data2016['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2016['Data'] = pd.to_datetime(data2016['Data'], format = "%Y %m %d")
data2016.sort_values(by=['Data'])
data2016=data2016[data2016['Valore']<1000]

grouped2016 = data2016.groupby(["Data"]).mean()

# %%
data2015 = data2015.reset_index()
data2015 = pd.merge(left=data2015[data2015['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2015['Data'] = pd.to_datetime(data2015['Data'], format = "%Y %m %d")
data2015.sort_values(by=['Data'])
data2015=data2015[data2015['Valore']<1000]

grouped2015 = data2015.groupby(["Data"]).mean()

# %%
data2014 = data2014.reset_index()
data2014 = pd.merge(left=data2014[data2014['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2014['Data'] = pd.to_datetime(data2014['Data'], format = "%Y %m %d")
data2014.sort_values(by=['Data'])
data2014=data2014[data2014['Valore']<1000]

grouped2014 = data2014.groupby(["Data"]).mean()

# %%
data2013 = data2013.reset_index()
data2013 = pd.merge(left=data2013[data2013['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2013['Data'] = pd.to_datetime(data2013['Data'], format = "%Y %m %d")
data2013.sort_values(by=['Data'])
data2013=data2013[data2013['Valore']<1000]

grouped2013 = data2013.groupby(["Data"]).mean()

# %%
data2012 = data2012.reset_index()
data2012 = pd.merge(left=data2012[data2012['Valore']>0], right=stazioni[stazioni['tipologia']=="Precipitazione"], how="inner",
                   left_on='IdSensore', right_on='idsensore')
data2012['Data'] = pd.to_datetime(data2012['Data'], format = "%Y %m %d")
data2012.sort_values(by=['Data'])
data2012=data2012[data2012['Valore']<1000]

grouped2012 = data2012.groupby(["Data"]).mean()

# %% [markdown]
# boxplot

# %%
lista=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.boxplot([grouped2012['Valore'][:365], grouped2012['Valore'][365:], grouped2013['Valore'], grouped2014['Valore'],
             grouped2015['Valore'], grouped2016['Valore'], grouped2017['Valore'], grouped2018['Valore'], grouped2019['Valore'],
             grouped2020['Valore'], grouped2021['Valore']], positions = lista, patch_artist = True)

plt.title("Boxplots of rain measurements by year")
#plt.hlines(y=50, xmin=2011, xmax=2021, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("millimiters of rain")
plt.xlabel("Year")
plt.rcParams["figure.figsize"] = (15,6)
#plt.legend()
plt.show()

# %% [markdown]
# Statistiche descrittive

# %%
descrittive = pd.concat([grouped2021['Valore'].describe(),grouped2020['Valore'].describe(), grouped2019['Valore'].describe(),
                        grouped2018['Valore'].describe(), grouped2017['Valore'].describe(), grouped2016['Valore'].describe(),
                        grouped2015['Valore'].describe(), grouped2014['Valore'].describe(), grouped2013['Valore'].describe(),
                        grouped2012['Valore'][365:].describe(), grouped2012['Valore'][:365].describe()],axis=1)
descrittive.columns=["2021","2020","2019","2018","2017","2016","2015","2014","2013","2012","2011"]
descrittive = descrittive.transpose()
descrittive.drop(columns='count')
# Out:
#           mean        std       min       25%       50%       75%         max
# 2021  4.401382   7.081801  0.200000  0.608234  1.832032  4.709177   50.939450
# 2020  4.854613   8.203849  0.175000  0.513125  2.026138  5.373506   55.394470
# 2019  6.179334  13.503811  0.180000  0.789167  2.361801  6.140602  163.500000
# 2018  4.855955   8.330504  0.190000  0.951724  2.368067  5.430882   85.800000
# 2017  3.952478   6.922426  0.183333  0.476630  1.344444  3.833327   48.737441
# 2016  4.608053   6.651573  0.180000  0.552222  2.011494  5.269338   35.032461
# 2015  4.153005   6.132473  0.185714  0.330326  1.701961  4.906084   39.925628
# 2014  6.596638   9.156777  0.185714  1.203125  3.178295  7.734513   69.951955
# 2013  5.190247   7.255651  0.200000  0.960000  2.680000  6.282450   54.751136
# 2012  5.370831   7.959847  0.200000  0.640247  2.024397  6.457389   51.000000
# 2011  4.273249   7.175688  0.100000  0.300000  1.450000  5.315827   55.655090

# %% [markdown]
# correlation matrix

# %%
df_corr = pd.DataFrame()

appo = grouped2021['Valore']
appo.index = range(len(appo))
df_corr["2021"] = appo

appo = pd.concat([grouped2020['Valore'][:59],grouped2020['Valore'][60:]])
appo.index = range(len(appo))
df_corr["2020"] = appo

appo = grouped2019['Valore']
appo.index = range(len(appo))
df_corr["2019"] = appo

appo = grouped2018['Valore']
appo.index = range(len(appo))
df_corr["2018"] = appo

appo = grouped2017['Valore']
appo.index = range(len(appo))
df_corr["2017"] = appo

appo = pd.concat([grouped2016['Valore'][:59],grouped2016['Valore'][60:]])
appo.index = range(len(appo))
df_corr["2016"] = appo

appo = grouped2015['Valore']
appo.index = range(len(appo))
df_corr["2015"] = appo

appo = grouped2014['Valore']
appo.index = range(len(appo))
df_corr["2014"] = appo

appo = grouped2013['Valore']
appo.index = range(len(appo))
df_corr["2013"] = appo

appo = pd.concat([grouped2012['Valore'][366:424],grouped2012['Valore'][425:]])
appo.index = range(len(appo))
df_corr["2012"] = appo

appo = grouped2012['Valore'][:365]
appo.index = range(len(appo))
df_corr["2011"] = appo

import seaborn as sn


rcParams['figure.figsize'] = 15,8

corrMatrix = df_corr.corr()
#sn.color_palette("flare", as_cmap=True)
sn.heatmap(corrMatrix, annot=True, vmin=0, vmax=1, cmap="flare").set(title='Correlation matrix between yearly rain time series')
plt.show()

# %% [markdown]
# Confronto tra serie storiche

# %%
plt.plot(df_corr["2021"],  label = "2021", color='lawngreen')
plt.plot(df_corr["2011"], label = "2011", color='turquoise')
plt.title("Comparison between rain measurements in 2011 and 2021")
#plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("millimiters of rain")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %%
plt.plot(df_corr["2017"],  label = "2017", color='lawngreen')
plt.plot(df_corr["2016"], label = "2016", color='turquoise')
plt.title("Comparison between rain measurements in 2016 and 2017")
#plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("millimiters of rain")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %%
plt.plot(df_corr["2016"],  label = "2016", color='lawngreen')
plt.plot(df_corr["2014"], label = "2014", color='turquoise')
plt.title("Comparison between rain measurements in 2014 and 2016")
#plt.hlines(y=50, xmin=0, xmax=365, colors='red', linestyles='-', lw=2, label='PM10 daily threshold')
plt.ylabel("millimiters of rain")
plt.xlabel("nth day of the year")
plt.legend()
plt.show()

# %% [markdown]
# Confronto tra densità

# %%
sn.distplot(df_corr["2021"], hist=False, axlabel='millimiters of rain', color = "mediumblue", label="2021").set(title='Histogram of millimiters of rain average values between 2011 and 2021')
sn.distplot(df_corr["2019"], hist=False, axlabel='millimiters of rain', color = "lawngreen", label="2019")
sn.distplot(df_corr["2017"], hist=False, axlabel='millimiters of rain', color = "turquoise", label="2017")
sn.distplot(df_corr["2015"], hist=False, axlabel='millimiters of rain', color = "pink", label="2015")
sn.distplot(df_corr["2013"], hist=False, axlabel='millimiters of rain', color = "gold", label="2013")
sn.distplot(df_corr["2011"], hist=False, axlabel='millimiters of rain', color = "red", label="2011")
#plt.axvline(x=50, color='grey', linestyle='-', lw=2, label='PM10 daily threshold')
plt.xlim(-5, 60)
plt.legend() 
plt.show()
# Out:
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\stefa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# scrittura csv per mappe

# %%
data2021.to_csv('pioggia2021.csv')
data2019.to_csv('pioggia2019.csv')
data2017.to_csv('pioggia2017.csv')
data2015.to_csv('pioggia2015.csv')
data2013.to_csv('pioggia2013.csv')
data2012[data2012['Data']<'2012-01-01'].to_csv('pioggia2011.csv')

# %%
stazioni['tipologia'].drop_duplicates()
# Out:
# 0            Altezza Neve
# 1          Precipitazione
# 3             Temperatura
# 4        Umidità Relativa
# 5      Radiazione Globale
# 7         Direzione Vento
# 12         Velocità Vento
# 37    Livello Idrometrico
# Name: tipologia, dtype: object
